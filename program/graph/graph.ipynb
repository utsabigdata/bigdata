# %%
import networkx as nx
# %matplotlib notebook

# %% [markdown]
# ## Undirected Graph Network

# %%
graph=nx.Graph()
graph.add_edge('A','B')
graph.add_edge('B','C')
graph.add_edge('C','F')
graph.add_edge('C','E')
graph.add_edge('E','D')
graph.add_edge('F','G')
nx.draw_networkx(graph)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Directed Graph Network

# %%
D=nx.DiGraph()
D.add_edge('A','B')
D.add_edge('B','C')
D.add_edge('C','F')
D.add_edge('C','E')
D.add_edge('E','D')
D.add_edge('F','G')
nx.draw_networkx(D)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Weighted Graph Network

# %%
G=nx.Graph()
G.add_edge('A','B', weight = 6)
G.add_edge('B','C', weight = 10)
G.add_edge('C','F', weight = 12)
G.add_edge('C','E', weight = 1)
G.add_edge('B','C', weight = 3)
G.add_edge('E','D', weight = 4)
G.add_edge('F','G', weight = 8)
nx.draw_networkx(G)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Signed Network

# %%
S=nx.Graph()
S.add_edge('A','B', sign = '+')
S.add_edge('B','C', sign = '+')
S.add_edge('C','F', sign = '-')
S.add_edge('C','E', sign = '+')
S.add_edge('B','C', sign = '+')
S.add_edge('E','D', sign = '-')
S.add_edge('F','G', sign = '-')
nx.draw_networkx(S)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Relation Network

# %%
R=nx.Graph()
R.add_edge('A','B', relation = 'mother')
R.add_edge('B','C', relation = 'friend')
R.add_edge('C','F', relation = 'father')
R.add_edge('C','E', relation = 'coworker')
R.add_edge('B','C', relation = 'friend')
R.add_edge('E','D', relation = 'sister')
R.add_edge('F','G', relation = 'friend')

# %% [markdown]
# ## MultiGraph Network

# %%
MG=nx.MultiGraph()
MG.add_edge('A','B', relation = 'mother')
MG.add_edge('A','B', relation = 'family')
MG.add_edge('B','C', relation = 'friend')
MG.add_edge('C','F', relation = 'father')
MG.add_edge('C','E', relation = 'coworker')
MG.add_edge('B','C', relation = 'friend')
MG.add_edge('E','D', relation = 'sister')
MG.add_edge('F','G', relation = 'friend')
# Out:
# 0

# %% [markdown]
# ## Graph with Weight and Attribute

# %%
G = nx.Graph()
G.add_edge('A','B', weight=6, relation = 'Family')
G.add_edge('B','C', weight=13, relation = 'Friend')
G.add_edge('C','F', weight=21, relation = 'Coworker')
G.add_edge('C','E', weight=25, relation = 'Neighbor')
G.add_edge('F','G', weight=9, relation = 'Friend')
G.add_edge('E','D', weight=2, relation = 'Coworker')
G.add_edge('E','I', weight=10, relation = 'Coworker')
G.add_edge('E','J', weight=15, relation = 'Family')
G.add_edge('E','H', weight=9, relation = 'Coworker')

# %% [markdown]
# ## List of all Edges

# %%
G.edges()
# Out:
# EdgeView([('D', 'E'), ('C', 'E'), ('C', 'B'), ('C', 'F'), ('E', 'J'), ('E', 'I'), ('E', 'H'), ('G', 'F'), ('B', 'A')])

# %% [markdown]
# ## List of all edges with attributes

# %%
G.edges(data=True)
# Out:
# EdgeDataView([('D', 'E', {'weight': 2, 'relation': 'Coworker'}), ('C', 'E', {'weight': 25, 'relation': 'Neighbor'}), ('C', 'B', {'weight': 13, 'relation': 'Friend'}), ('C', 'F', {'weight': 21, 'relation': 'Coworker'}), ('E', 'J', {'weight': 15, 'relation': 'Family'}), ('E', 'I', {'weight': 10, 'relation': 'Coworker'}), ('E', 'H', {'weight': 9, 'relation': 'Coworker'}), ('G', 'F', {'weight': 9, 'relation': 'Friend'}), ('B', 'A', {'weight': 6, 'relation': 'Family'})])

# %%
G.edges(data='relation')
# Out:
# EdgeDataView([('D', 'E', 'Coworker'), ('C', 'E', 'Neighbor'), ('C', 'B', 'Friend'), ('C', 'F', 'Coworker'), ('E', 'J', 'Family'), ('E', 'I', 'Coworker'), ('E', 'H', 'Coworker'), ('G', 'F', 'Friend'), ('B', 'A', 'Family')])
