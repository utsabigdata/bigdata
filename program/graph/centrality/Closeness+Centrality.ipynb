# %%
import networkx as nx
import numpy as np
import pandas as pd
# %matplotlib notebook

# %%
G1 = nx.Graph()
G1.add_edges_from([(1, 6),
                   (1, 9),
                   (7, 0),
                   (4, 5),
                   (0, 2),
                   (2, 10),
                   (2, 14),
                   (2, 4),
                   (2, 3),
                   (4, 11),
                   (1,7),
                   (7, 8),
                   (7, 12),
                   (7, 13)])
nx.draw_networkx(G1,node_color='red')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
print(nx.closeness_centrality(G1))
# Out:
# {0: 0.4666666666666667, 1: 0.35, 2: 0.45161290322580644, 3: 0.3181818181818182, 4: 0.35, 5: 0.2641509433962264, 6: 0.2641509433962264, 7: 0.45161290322580644, 8: 0.3181818181818182, 9: 0.2641509433962264, 10: 0.3181818181818182, 11: 0.2641509433962264, 12: 0.3181818181818182, 13: 0.3181818181818182, 14: 0.3181818181818182}
