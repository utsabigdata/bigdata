# %%
import networkx as nx
import numpy as np
import pandas as pd
# %matplotlib notebook

# %%
k = nx.chordal_cycle_graph(20)
nx.draw(k,node_color='green',node_size=500,with_labels=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
print(nx.info(k))
# Out:
# Name: chordal_cycle_graph(20)
# Type: MultiGraph
# Number of nodes: 20
# Number of edges: 60
# Average degree:   6.0000

# %%
dc=nx.degree_centrality(k)
print (dc)
print ("degree centrality =", max(zip(dc.values(), dc.keys())))
# Out:
# {0: 0.3684210526315789, 1: 0.47368421052631576, 2: 0.2631578947368421, 3: 0.2631578947368421, 4: 0.47368421052631576, 5: 0.3684210526315789, 6: 0.2631578947368421, 7: 0.2631578947368421, 8: 0.2631578947368421, 9: 0.47368421052631576, 10: 0.2631578947368421, 11: 0.2631578947368421, 12: 0.2631578947368421, 13: 0.2631578947368421, 14: 0.2631578947368421, 15: 0.2631578947368421, 16: 0.47368421052631576, 17: 0.2631578947368421, 18: 0.2631578947368421, 19: 0.2631578947368421}
# degree centrality = (0.47368421052631576, 16)

# %%
bc=nx.betweenness_centrality(k)
print (bc)
print ("betweeness centrality =", max(zip(bc.values(), bc.keys())))
# Out:
# {0: 0.012183235867446393, 1: 0.12482131254061077, 2: 0.03414554905782976, 3: 0.018031189083820662, 4: 0.27296946068875894, 5: 0.04369720597790773, 6: 0.02729044834307992, 7: 0.04191033138401559, 8: 0.021929824561403504, 9: 0.2807667316439246, 10: 0.04340480831708901, 11: 0.02729044834307992, 12: 0.061403508771929814, 13: 0.06903833658219621, 14: 0.030051981806367773, 15: 0.012183235867446393, 16: 0.12751786874593896, 17: 0.06003898635477583, 18: 0.0652046783625731, 19: 0.029629629629629627}
# betweeness centrality = (0.2807667316439246, 9)

# %%
cc=nx.closeness_centrality(k)
print (cc)
print ("closeness centrality =", max(zip(cc.values(), cc.keys())))
# Out:
# {0: 0.3584905660377358, 1: 0.48717948717948717, 2: 0.4523809523809524, 3: 0.4634146341463415, 4: 0.5757575757575758, 5: 0.4222222222222222, 6: 0.3958333333333333, 7: 0.4418604651162791, 8: 0.475, 9: 0.5757575757575758, 10: 0.4222222222222222, 11: 0.40425531914893614, 12: 0.4634146341463415, 13: 0.4634146341463415, 14: 0.40425531914893614, 15: 0.3584905660377358, 16: 0.48717948717948717, 17: 0.475, 18: 0.4523809523809524, 19: 0.3958333333333333}
# closeness centrality = (0.5757575757575758, 9)
