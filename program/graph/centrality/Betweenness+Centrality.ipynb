# %%
import networkx as nx
import numpy as np
import pandas as pd
# %matplotlib notebook

# %%
G1 = nx.Graph()
G1.add_edges_from([(1, 6),
                   (1, 9),
                   (7, 0),
                   (4, 5),
                   (0, 2),
                   (2, 10),
                   (2, 14),
                   (2, 4),
                   (2, 3),
                   (4, 11),
                   (1,7),
                   (7, 8),
                   (7, 12),
                   (7, 13)])
nx.draw_networkx(G1,node_color='red', node_size=1000)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
print(nx.betweenness_centrality(G1))
# Out:
# {0: 0.5384615384615385, 1: 0.27472527472527475, 2: 0.6593406593406594, 3: 0.0, 4: 0.27472527472527475, 5: 0.0, 6: 0.0, 7: 0.6593406593406594, 8: 0.0, 9: 0.0, 10: 0.0, 11: 0.0, 12: 0.0, 13: 0.0, 14: 0.0}
