# %%
import networkx as nx
import numpy as np
import pandas as pd
# %matplotlib notebook

# %%
G1 = nx.Graph()
G1.add_edges_from([(1, 6),
                   (1, 9),
                   (7, 0),
                   (4, 5),
                   (0, 2),
                   (2, 10),
                   (2, 14),
                   (2, 4),
                   (2, 3),
                   (4, 11),
                   (1,7),
                   (7, 8),
                   (7, 12),
                   (7, 13)])
nx.draw_networkx(G1,node_color='red', node_size=1000)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
centrality = nx.eigenvector_centrality(G1)
print (centrality)
# Out:
# {0: 0.37526518024883654, 1: 0.27197436610762915, 2: 0.4765095820062332, 3: 0.187632590124428, 4: 0.27197436610762915, 5: 0.10709485994341066, 6: 0.10709485994341066, 7: 0.4765095820062332, 8: 0.187632590124428, 9: 0.10709485994341066, 10: 0.187632590124428, 11: 0.10709485994341066, 12: 0.187632590124428, 13: 0.187632590124428, 14: 0.187632590124428}

# %%
print ("centrality =", max(zip(centrality.values(), centrality.keys())))
# Out:
# centrality = (0.4765095820062332, 7)
