# %%
import networkx as nx
import numpy as np
import pandas as pd
# %matplotlib notebook

# %%
G1 = nx.Graph()
G1.add_edges_from([(1, 6),
                   (1, 9),
                   (7, 0),
                   (4, 5),
                   (0, 2),
                   (2, 10),
                   (2, 14),
                   (2, 4),
                   (2, 3),
                   (4, 11),
                   (1,7),
                   (7, 8),
                   (7, 12),
                   (7, 13)])
nx.draw_networkx(G1,node_color='cyan')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
print(nx.degree_centrality(G1))
# Out:
# {0: 0.14285714285714285, 1: 0.21428571428571427, 2: 0.3571428571428571, 3: 0.07142857142857142, 4: 0.21428571428571427, 5: 0.07142857142857142, 6: 0.07142857142857142, 7: 0.3571428571428571, 8: 0.07142857142857142, 9: 0.07142857142857142, 10: 0.07142857142857142, 11: 0.07142857142857142, 12: 0.07142857142857142, 13: 0.07142857142857142, 14: 0.07142857142857142}
