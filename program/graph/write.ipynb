# %% [markdown]
# ## Write graph object into Python pickle format

# %%
# create a random graph
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
G = nx.path_graph(5)
nx.draw(G,with_labels=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#write file to disk
nx.write_gpickle(G,'path.gpickle')

# %%
import os
os.listdir()
# Out:
# ['Untitled1.ipynb',
#  'route.ipynb',
#  'write.ipynb',
#  'path.gpickle',
#  '.ipynb_checkpoints',
#  'degree.ipynb',
#  'Untitled.ipynb',
#  'graph.ipynb',
#  'Untitled2.ipynb']

# %% [markdown]
# ## Read graph object in Python pickle format¶

# %%
data = nx.read_gpickle('path.gpickle')
nx.draw(data, with_labels=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
print(nx.info(data))
# Out:
# Name:
# Type: Graph
# Number of nodes: 5
# Number of edges: 4
# Average degree:   1.6000
